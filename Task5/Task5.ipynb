# %% [markdown]
# # Prodigy InfoTech DS Task 5.

# %% [markdown]
# Analyze traffic accident data to identify patterns related to road conditions, weather, and time of day. Visualize accident hotspots and contributing factors.

# %% [markdown]
# ## Done By:- Domala Venkata Lakshmi Karthik.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
#--------------------------------------------------
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
#--------------------------------------------------
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # USA-Accidents-EDA

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**

# %% [markdown]
# *TODO-talk about EDA
# TODO- talk about data source (where we got it from , what it contains, why USEFUL?)*
# * 1- Kaggle
# * 2- useful inforamtion about accidents
# * 3- for preventing accidents

# %% [markdown]
# # Preparation and Cleaning

# %%
df = pd.read_csv("US_Accidents_May19_Migrated Data.csv")
df
# Out:
#         Airport_Code  Amenity Astronomical_Twilight   Bump Calculation1  \
# 0                NaN    False                   Day  False    Remaining
# 1               KDWH    False                   Day  False    Remaining
# 2               KDSM    False                   Day  False    Remaining
# 3               KCPS    False                   Day  False    Remaining
# 4               KXBP    False                   Day  False    Remaining
# ...              ...      ...                   ...    ...          ...
# 2243934         KBKF    False                   Day  False    Remaining
# 2243935         KBKF    False                   Day  False    Remaining
# 2243936         KCOS    False                   Day  False    Remaining
# 2243937         KCOS    False                   Day  False    Remaining
# 2243938         KBKF    False                   Day  False    Remaining
#
#                      City Civil_Twilight  count of Bump  Count of Crossing  \
# ...

# %%
df.describe()
# Out:
#        count of Bump  Count of Crossing  count Traffic Signal        End_Lat  \
# count   2.243939e+06       2.243939e+06          2.243939e+06  516762.000000
# mean    1.065091e-04       5.427197e-02          1.598297e-01      37.443109
# std     1.031978e-02       2.265536e-01          3.664481e-01       5.126585
# min     0.000000e+00       0.000000e+00          0.000000e+00      24.570110
# 25%     0.000000e+00       0.000000e+00          0.000000e+00      33.887450
# 50%     0.000000e+00       0.000000e+00          0.000000e+00      38.038480
# 75%     0.000000e+00       0.000000e+00          0.000000e+00      41.393320
# max     1.000000e+00       1.000000e+00          1.000000e+00      49.075000
#
#              End_Lng         Number      Severity  Temperature(F)  \
# count  516762.000000  785537.000000  2.243939e+06    2.181674e+06
# mean      -96.527543    5625.281008  2.382692e+00    6.123244e+01
# std        17.986406   11071.872897  5.488029e-01    1.914616e+01
# ...

# %%
excluded_describe = df.describe(exclude ='number' )
excluded_describe
# Out:
#        Airport_Code  Amenity Astronomical_Twilight     Bump Calculation1  \
# count       2220275  2243939               2243861  2243939      2243939
# unique         1895        2                     2        2            3
# top            KMCJ    False                   Day    False    Remaining
# freq          46678  2217962               1959792  2243700      1573772
#
#            City Civil_Twilight  Country       County Crossing  ...   Street  \
# count   2243871        2243861  2243939      2243939  2243939  ...  2243939
# unique    11077              2        1         1682        2  ...   120397
# top     Houston            Day       US  Los Angeles    False  ...    I-5 N
# freq      76449        1761390  2243939       171981  2122156  ...    25836
#
#        Sunrise_Sunset    Timezone Traffic_Calming Traffic_Signal Turning_Loop  \
# count         2243861     2241798         2243939        2243939      2243939
# ...

# %%
df.columns
for column in df.columns:
    print(column)
# Out:
# Airport_Code
# Amenity
# Astronomical_Twilight
# Bump
# Calculation1
# City
# Civil_Twilight
# count of Bump
# Count of Crossing
# count Traffic Signal
# Country
# County
# Crossing
# Description
# End_Lat
# End_Lng
# End_Time
# Give_Way
# ID
# Junction
# Nautical_Twilight
# No_Exit
# Number
# Railway
# Roundabout
# Severity
# Side
# Source
# Start_Time
# State
# Station
# Stop
# Street
# Sunrise_Sunset
# Temperature(F)
# Timezone
# Traffic_Calming
# Traffic_Signal
# Turning_Loop
# Visibility(mi)
# Weather_Condition
# Weather_Timestamp
# Wind_Direction
# Zipcode
# Count of accidents
# count of county
# Distance(mi)
# Humidity(%)
# Number of Records
# Precipitation(in)
# Pressure(in)
# Records
# Start_Lat
# Start_Lng
# TMC
# Wind_Chill(F)
# Wind_Speed(mph)

# %%
numeric = ['int64','int32','int16','float16','float32','float64']
df_numeric = df.select_dtypes(include=numeric)
len(df_numeric.columns)
# Out:
# 22

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2243939 entries, 0 to 2243938
# Data columns (total 57 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Airport_Code           object
#  1   Amenity                bool
#  2   Astronomical_Twilight  object
#  3   Bump                   bool
#  4   Calculation1           object
#  5   City                   object
#  6   Civil_Twilight         object
#  7   count of Bump          int64
#  8   Count of Crossing      int64
#  9   count Traffic Signal   int64
#  10  Country                object
#  11  County                 object
#  12  Crossing               bool
#  13  Description            object
#  14  End_Lat                float64
#  15  End_Lng                float64
#  16  End_Time               object
#  17  Give_Way               bool
#  18  ID                     object
#  19  Junction               bool
#  20  Nautical_Twilight      object
#  21  No_Exit                bool
# ...

# %% [markdown]
# **FIND THE MISSING VALUES**

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# Airport_Code               23664
# Amenity                        0
# Astronomical_Twilight         78
# Bump                           0
# Calculation1                   0
# City                          68
# Civil_Twilight                78
# count of Bump                  0
# Count of Crossing              0
# count Traffic Signal           0
# Country                        0
# County                         0
# Crossing                       0
# Description                    1
# End_Lat                  1727177
# End_Lng                  1727177
# End_Time                       0
# Give_Way                       0
# ID                             0
# Junction                       0
# Nautical_Twilight             78
# No_Exit                        0
# Number                   1458402
# Railway                        0
# Roundabout                     0
# Severity                       0
# Side                           1
# Source                         0
# ...

# %%
df_missing_values = missing_values[missing_values != 0].sort_values(ascending=True)

df_missing_values
# Plot the missing values
plt.figure(figsize=(10, 6))
df_missing_values.plot(kind='barh', color='skyblue')
plt.title('Number of Missing Values per Column')
plt.xlabel('Columns')
plt.ylabel('Number of Missing Values')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # ****Now we will delete all those above missing values label as they are of no use with the exception of the last 9 as they have not much missing values****

# %%
df.columns
#hehe , we now have the correct filtered columns! yipee!
# Out:
# Index(['Airport_Code', 'Amenity', 'Astronomical_Twilight', 'Bump',
#        'Calculation1', 'City', 'Civil_Twilight', 'count of Bump',
#        'Count of Crossing', 'count Traffic Signal', 'Country', 'County',
#        'Crossing', 'Description', 'End_Lat', 'End_Lng', 'End_Time', 'Give_Way',
#        'ID', 'Junction', 'Nautical_Twilight', 'No_Exit', 'Number', 'Railway',
#        'Roundabout', 'Severity', 'Side', 'Source', 'Start_Time', 'State',
#        'Station', 'Stop', 'Street', 'Sunrise_Sunset', 'Temperature(F)',
#        'Timezone', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop',
#        'Visibility(mi)', 'Weather_Condition', 'Weather_Timestamp',
#        'Wind_Direction', 'Zipcode', 'Count of accidents', 'count of county',
#        'Distance(mi)', 'Humidity(%)', 'Number of Records', 'Precipitation(in)',
#        'Pressure(in)', 'Records', 'Start_Lat', 'Start_Lng', 'TMC',
#        'Wind_Chill(F)', 'Wind_Speed(mph)'],
#       dtype='object')

# %% [markdown]
# # Data Visulization
# **columns we will be analysing:**
# * city
# * start time
# * Temperature
# * Weather Condition

# %%
cities = df.City.unique()
len(cities)
# Out:
# 11078

# %%
city_by_accidents = df.City.value_counts()
city_by_accidents
# Out:
# City
# Houston          76449
# Charlotte        51791
# Los Angeles      49621
# Dallas           46492
# Austin           45683
#                  ...
# Frenchburg           1
# Rainsville           1
# Tilleda              1
# Grand View           1
# Council Grove        1
# Name: count, Length: 11077, dtype: int64

# %%
city_by_accidents[:20]
# Out:
# City
# Houston          76449
# Charlotte        51791
# Los Angeles      49621
# Dallas           46492
# Austin           45683
# Atlanta          31042
# Raleigh          30705
# Miami            24853
# Orlando          22087
# Baton Rouge      21689
# Oklahoma City    21666
# Nashville        20448
# Seattle          19957
# Sacramento       18214
# San Antonio      16963
# Minneapolis      15762
# San Diego        15610
# Omaha            15530
# Phoenix          15401
# Indianapolis     14846
# Name: count, dtype: int64

# %%
'detroit' in df.City
'Detroit' in df.City
# Out:
# False

# %% [markdown]
# **THERE IS NO DETROIT SO DETROIT HAS LOW ACCIDENTS**

# %%
city_by_accidents[:20].plot(kind='barh')
# Out:
# <Axes: ylabel='City'>

# %% [markdown]
# # los angeles , charlotte, houston should implement measures

# %%
sns.distplot(city_by_accidents)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8552\475156009.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(city_by_accidents)
# <Axes: xlabel='count', ylabel='Density'>

# %%
highest_accident = city_by_accidents[city_by_accidents>=1000]
lowest_accident = city_by_accidents[city_by_accidents<1000]

# %%
len(highest_accident)/len(cities)
# Out:
# 0.03240657158331829

# %%
sns.histplot(highest_accident,log_scale=True)
# Out:
# <Axes: xlabel='count', ylabel='Count'>

# %% [markdown]
# **MOST CITIES HAVE ACCIDENTS CLOSE TO 1000**

# %%
sns.histplot(lowest_accident,log_scale=True)
# Out:
# <Axes: xlabel='count', ylabel='Count'>

# %%
city_by_accidents[city_by_accidents == 1]
# Out:
# City
# South China      1
# Adamsburg        1
# Emington         1
# West Halifax     1
# Sims             1
#                 ..
# Frenchburg       1
# Rainsville       1
# Tilleda          1
# Grand View       1
# Council Grove    1
# Name: count, Length: 1467, dtype: int64

# %% [markdown]
# **START TIME**

# %%
#pd.to_datetime('Start_Time', format = "%d/%m/%y")
df.Start_Time = pd.to_datetime(df.Start_Time)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8552\2010393242.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df.Start_Time = pd.to_datetime(df.Start_Time)

# %%
sns.distplot(df.Start_Time.dt.hour,bins=20,kde=False)
sns.set_style('whitegrid')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8552\2146065868.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.hour,bins=20,kde=False)

# %% [markdown]
# **MOST OF THE DEATHS ARE IN BETWEEN 5am to 9 am ANd then after 3pm to 5 pm which also suggests that these times are job times and people are arriving or going for job at this time .
# moreover,
# it also suggests that we shouldnt take much stress for the job and people should be given lineancy for the time of arrival .
# Public Transport: Promote the use of public transport to decrease traffic volume.
# Safety Measures: Implement stricter traffic regulations during these hours.**

# %%
sns.distplot(df.Start_Time.dt.weekday,bins=7,norm_hist=True,kde=False)
plt.grid
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8552\1391992391.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.weekday,bins=7,norm_hist=True,kde=False)

# %% [markdown]
# # RESULTS
# **its obvious that all working days have the most deaths through car accidents which proves that we have to improve traffic systems and remove stress out of peoples brains **

# %%
sunday_time =df.Start_Time[df.Start_Time.dt.day_of_week==6]

# %%
sns.distplot(sunday_time.dt.hour, bins=24, norm_hist=True, kde = False)
plt.grid()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8552\4238717723.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sunday_time.dt.hour, bins=24, norm_hist=True, kde = False)

# %% [markdown]
# # RESULTS
# **most people die around 10AM to 3pm**

# %%
sns.distplot(df.Start_Time.dt.month,bins=12,kde=False)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8552\2954795542.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.month,bins=12,kde=False)

# %% [markdown]
# **MOST DEATHS ARE IN AUTUMN AND WINTER**

# %%
df.Start_Time.dt.year
# Out:
# 0          2016
# 1          2016
# 2          2016
# 3          2016
# 4          2016
#            ...
# 2243934    2017
# 2243935    2017
# 2243936    2018
# 2243937    2017
# 2243938    2017
# Name: Start_Time, Length: 2243939, dtype: int32

# %%
df.Source
# Out:
# 0          MapQuest
# 1          MapQuest
# 2          MapQuest
# 3          MapQuest
# 4          MapQuest
#              ...
# 2243934    MapQuest
# 2243935    MapQuest
# 2243936    MapQuest
# 2243937    MapQuest
# 2243938    MapQuest
# Name: Source, Length: 2243939, dtype: object

# %%
df_2016= df.Start_Time.dt.year == 2016
df_2016
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 2243934    False
# 2243935    False
# 2243936    False
# 2243937    False
# 2243938    False
# Name: Start_Time, Length: 2243939, dtype: bool

# %%
if 'MapQuest' in df.Source:
    print('Yes')

# %% [markdown]
# # ANALYSIS ON ACCIDENTS BY YEARS

# %%
df_2016= df[df.Start_Time.dt.year == 2016]
sns.distplot(df_2016.Start_Time.dt.month, bins=12, norm_hist=True, kde = False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8552\3990459467.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2016.Start_Time.dt.month, bins=12, norm_hist=True, kde = False)
# <Axes: xlabel='Start_Time'>

# %%
df_2017= df[df.Start_Time.dt.year == 2017]
sns.distplot(df_2017.Start_Time.dt.month, bins=12, norm_hist=True, kde = False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8552\1464067620.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2017.Start_Time.dt.month, bins=12, norm_hist=True, kde = False)
# <Axes: xlabel='Start_Time'>

# %%
df_2018= df[df.Start_Time.dt.year == 2018]
sns.distplot(df_2018.Start_Time.dt.month, bins=12, norm_hist=True, kde = False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8552\1750430829.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2018.Start_Time.dt.month, bins=12, norm_hist=True, kde = False)
# <Axes: xlabel='Start_Time'>

# %%
df_2019= df[df.Start_Time.dt.year == 2019]
sns.distplot(df_2019.Start_Time.dt.month, bins=12, norm_hist=True, kde = False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8552\3584003554.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2019.Start_Time.dt.month, bins=12, norm_hist=True, kde = False)
# <Axes: xlabel='Start_Time'>

# %% [markdown]
# **THIS GRAPH IS UNUSUAL AND OFFTREND SO THEIR MUST BE SOMETHING WRONG WITH THE SOURCE**

# %%
df_2019 = df[df.Start_Time.dt.year == 2019]
df_2019_Mapquest = df_2019[df_2019.Source == 'MapQuest']
sns.distplot(df_2019_Mapquest.Start_Time.dt.month,bins=12,norm_hist=True,kde=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8552\813558088.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2019_Mapquest.Start_Time.dt.month,bins=12,norm_hist=True,kde=False)
# <Axes: xlabel='Start_Time'>

# %%
df_2018= df[df.Start_Time.dt.year == 2018]
df_2018_Bing= df_2018[df_2018.Source == 'Bing']
sns.distplot(df_2018_Bing.Start_Time.dt.month, bins=12, norm_hist=True, kde = False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8552\3427322095.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2018_Bing.Start_Time.dt.month, bins=12, norm_hist=True, kde = False)
# <Axes: xlabel='Start_Time'>

# %%
df_2018= df[df.Start_Time.dt.year == 2018]
df_2018_MapQuest= df_2018[df_2018.Source == 'MapQuest']
sns.distplot(df_2018_MapQuest.Start_Time.dt.month, bins=12, norm_hist=True, kde = False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8552\3932671997.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2018_MapQuest.Start_Time.dt.month, bins=12, norm_hist=True, kde = False)
# <Axes: xlabel='Start_Time'>

# %% [markdown]
# **THERE SEEMS TO BE AN ISSUE EITHER WITH MAPQUEST OR BING**

# %%
df_2016= df[df.Start_Time.dt.year == 2016]
df_2016_Bing= df_2016[df_2016.Source == 'Bing']
sns.distplot(df_2016_Bing.Start_Time.dt.month, bins=12, norm_hist=True, kde = False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8552\1381581979.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2016_Bing.Start_Time.dt.month, bins=12, norm_hist=True, kde = False)
# <Axes: xlabel='Start_Time'>

# %%
df_2016= df[df.Start_Time.dt.year == 2016]
df_2016_Bing= df_2016[df_2016.Source == 'MapQuest']
sns.distplot(df_2016_Bing.Start_Time.dt.month, bins=12, norm_hist=True, kde = False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8552\2312698322.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2016_Bing.Start_Time.dt.month, bins=12, norm_hist=True, kde = False)
# <Axes: xlabel='Start_Time'>

# %%
df.Source.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **WE SHOULD IGNORE BING DATA**

# %% [markdown]
# **START LATITUDE AND LONGITUDE **

# %%
df.Start_Lat
# Out:
# 0          39.852940
# 1          30.159246
# 2          41.586887
# 3          38.634579
# 4          32.930958
#              ...
# 2243934    39.709507
# 2243935    39.707298
# 2243936    38.833813
# 2243937    38.795475
# 2243938    39.707298
# Name: Start_Lat, Length: 2243939, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -75.461739
# 1          -95.510826
# 2          -93.806496
# 3          -90.186806
# 4          -97.641068
#               ...
# 2243934   -104.814987
# 2243935   -104.922256
# 2243936   -104.821724
# 2243937   -104.803535
# 2243938   -104.922256
# Name: Start_Lng, Length: 2243939, dtype: float64

# %%
sample_df = df.sample(int(0.1*len(df)))

# %%
sns.scatterplot(x=sample_df.Start_Lng,y=sample_df.Start_Lat)
# Out:
# <Axes: xlabel='Start_Lng', ylabel='Start_Lat'>

# %%
import folium
from folium.plugins import HeatMap
lat_lng_pairs = list(zip([sample_df.Start_Lat, sample_df.Start_Lng]))
Map = folium.Map()
heat_data = [[row['Start_Lat'], row['Start_Lng']] for index, row in sample_df.iterrows()]
HeatMap(heat_data).add_to(Map)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# # Main points

# %% [markdown]
# 1. What is the source of the accident data?
#
# * The data comes from two primary sources: MapQuest and Bing. These sources provide information on accidents reported across various regions in the US.
# 2. How many records are there in the dataset?
#
# * The dataset contains approximately 2 million records of accidents.
# 3. What time period does the dataset cover?
#
# * Specify the range of dates the dataset covers, such as from January 1, 2016, to December 31, 2021
# 4. Which states have the highest number of accidents?
#
# * Houston,Charlotte,Los Angeles

# %% [markdown]
# # SUMMARY and Conclusion

# %% [markdown]
# * No data from New York
# * The number of accidents per city decreases exponentially
# * less than 3% of cities have more than 1000 yearly accidents
# * Over 1400 cities have reportd just one accident
# * MOST DEATHS ARE IN AUTUMN AND WINTER
# * most people die around 10AM to 3pm
# * most people die around 5AM to 10AM on working days
